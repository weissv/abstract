# %%
# !pip install -q -r requirements.txt
# !pip install -q bitsandbytes accelerate
from huggingface_hub import notebook_login
notebook_login()
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 19.9 MB/s eta 0:00:00:00:0100:01
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !python experiments/01_baseline.py
# Out:
# python3: can't open file '/content/experiments/01_baseline.py': [Errno 2] No such file or directory

# %%
# !python experiments/02_patching.py
# Out:
# python3: can't open file '/content/experiments/02_patching.py': [Errno 2] No such file or directory
